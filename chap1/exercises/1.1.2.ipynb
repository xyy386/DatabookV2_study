# %%
import numpy as np

# %%
X = np.random.rand(5,3)
X
# Out:
# array([[0.96592996, 0.28299329, 0.206719  ],
#        [0.00699143, 0.97423529, 0.72391449],
#        [0.63460715, 0.59876644, 0.45863119],
#        [0.48690685, 0.36615198, 0.33619387],
#        [0.01458437, 0.80789015, 0.62825799]])

# %%
U, Sigma, VT = np.linalg.svd(X, full_matrices=True)

# %%
U_hat, Sigma_hat, VT_hat = np.linalg.svd(X, full_matrices=False)
