# %%
import numpy as np

# %%
X = np.random.rand(5,3)
X
# Out:
# array([[0.7178682 , 0.75723305, 0.35333908],
#        [0.87233196, 0.12617935, 0.44134062],
#        [0.60908195, 0.73647523, 0.06479602],
#        [0.36156657, 0.60021133, 0.11806179],
#        [0.09448737, 0.51742602, 0.38349404]])

# %%
U, Sigma, VT = np.linalg.svd(X, full_matrices=True)

# %%
U_hat, Sigma_hat, VT_hat = np.linalg.svd(X, full_matrices=False)
